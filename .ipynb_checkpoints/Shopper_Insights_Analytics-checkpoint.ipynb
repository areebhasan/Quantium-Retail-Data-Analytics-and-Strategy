# %% [markdown]
# # **Woolworths Shopper Insights: A Deep Dive into Consumer Behavior Analytics**
#
# ### *By Areeb Hasan*😊
#
# ---
#
# ## **Introduction**
#
# This notebook presents a comprehensive analysis of customer purchasing behavior within the retail sector, focusing on the chip category at Woolworths supermarket. The objective is to derive actionable insights that can inform the supermarket’s strategic planning, particularly in the areas of marketing, product placement, and inventory management.
#
# To achieve this, the analysis is structured as follows:
#
# 1. **Data Preparation:**
#    - Importing and cleaning transaction and customer data.
#    - Ensuring the data is ready for analysis by handling missing values, correcting data types, and removing irrelevant entries.
#
# 2. **Exploratory Data Analysis (EDA):**
#    - Initial exploration of the dataset to uncover key trends and patterns.
#    - Visualising data to gain insights into sales performance, customer demographics, and product preferences.
#
# 3. **Segment Analysis:**
#    - Identifying and analyzing different customer segments based on their purchasing behavior.
#    - Examining which segments contribute most to chip sales and their brand preferences.
#
# 4. **Statistical Testing:**
#    - Conducting statistical tests (e.g., T-tests) to compare sales performance across customer segments.
#    - Validating whether observed differences in purchasing behavior are statistically significant.
#
# 5. **Brand Affinity Analysis:**
#    - Assessing the affinity of different customer segments toward various chip brands.
#    - Identifying the brands that are most and least favored by key customer segments.
#
# This structured approach will enable us to provide data-driven recommendations that can enhance the supermarket’s ability to target high-value customers, optimize product offerings, and ultimately, increase sales in the chip category.

# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Checking Path

# %%
import os

# Define the path you want to list
directory_path = "/Users/areebhasan/Documents/Data Science/Quantium-Retail-Data-Analytics-and-Strategy/"

# List the contents of the directory
print(os.listdir(directory_path))
# Out:
# ['QVI_transaction_data.xlsx', 'Data_Prep&Analytics.ipynb', '.DS_Store', 'QVI_purchase_behaviour.csv', 'README.md', 'QVI_transaction_data.csv', '.gitattributes', '.ipynb_checkpoints', '.git']

# %% [markdown]
# #### Loading the datasets

# %%
file_path = "/Users/areebhasan/Documents/Data Science/Quantium-Retail-Data-Analytics-and-Strategy/" #Path to be changed once downloaded from Github

transaction_data = pd.read_csv(f"{file_path}QVI_transaction_data.csv")
customer_data = pd.read_csv(f"{file_path}QVI_purchase_behaviour.csv")

# %% [markdown]
# #### Exploratory Data Analysis

# %%
transaction_data.info()
transaction_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
# ...

# %% [markdown]
# #### Changing date type

# %%
if transaction_data['DATE'].dtype in ['int64', 'float64']:
    transaction_data['DATE'] = pd.to_datetime(transaction_data['DATE'], origin='1899-12-30', unit='D')

# %% [markdown]
# #### Examine Product Names

# %%
prod_name_summary = transaction_data['PROD_NAME'].value_counts() #kind of similar to group by in SQL
prod_name_summary.head(20)
# Out:
# PROD_NAME
# Kettle Mozzarella   Basil & Pesto 175g      3304
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    3296
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    3269
# Tyrrells Crisps     Ched & Chives 165g      3268
# Cobs Popd Sea Salt  Chips 110g              3265
# Kettle 135g Swt Pot Sea Salt                3257
# Tostitos Splash Of  Lime 175g               3252
# Infuzions Thai SweetChili PotatoMix 110g    3242
# Smiths Crnkle Chip  Orgnl Big Bag 380g      3233
# Thins Potato Chips  Hot & Spicy 175g        3229
# Kettle Sensations   Camembert & Fig 150g    3219
# Doritos Corn Chips  Cheese Supreme 170g     3217
# Pringles Barbeque   134g                    3210
# Doritos Corn Chip Mexican Jalapeno 150g     3204
# Kettle Sweet Chilli And Sour Cream 175g     3200
# Smiths Crinkle Chips Salt & Vinegar 330g    3197
# Thins Chips Light&  Tangy 175g              3188
# Dorito Corn Chp     Supreme 380g            3185
# Pringles Sweet&Spcy BBQ 134g                3177
# ...

# %% [markdown]
# #### Checking Salsa products as they are not classified as Chips

# %%
salsa_products = prod_name_summary[prod_name_summary.index.str.contains("salsa", case=False)]
num_salsa_products = salsa_products.sum()

print(f"Number of 'salsa' products: {num_salsa_products}")

print(salsa_products)
# Out:
# Number of 'salsa' products: 18094
# PROD_NAME
# Old El Paso Salsa   Dip Chnky Tom Ht300g    3125
# Old El Paso Salsa   Dip Tomato Med 300g     3114
# Old El Paso Salsa   Dip Tomato Mild 300g    3085
# Woolworths Mild     Salsa 300g              1491
# Doritos Salsa Mild  300g                    1472
# Smiths Crinkle Cut  Tomato Salsa 150g       1470
# Red Rock Deli SR    Salsa & Mzzrlla 150g    1458
# Doritos Salsa       Medium 300g             1449
# Woolworths Medium   Salsa 300g              1430
# Name: count, dtype: int64

# %% [markdown]
# #### Removing Salsa products except the Chips with Salsa taste

# %%
# List of specific salsa products we need to keep
products_to_keep = [
    "Smiths Crinkle Cut  Tomato Salsa 150g",
    "Red Rock Deli SR    Salsa & Mzzrlla 150g"
]

transaction_data = transaction_data[
    ~transaction_data['PROD_NAME'].str.contains("salsa", case=False) |
    transaction_data['PROD_NAME'].isin(products_to_keep)
]

print(transaction_data['PROD_NAME'].value_counts())
# Out:
# PROD_NAME
# Kettle Mozzarella   Basil & Pesto 175g      3304
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    3296
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    3269
# Tyrrells Crisps     Ched & Chives 165g      3268
# Cobs Popd Sea Salt  Chips 110g              3265
#                                             ...
# Sunbites Whlegrn    Crisps Frch/Onin 90g    1432
# RRD Pc Sea Salt     165g                    1431
# NCC Sour Cream &    Garden Chives 175g      1419
# French Fries Potato Chips 175g              1418
# WW Crinkle Cut      Original 175g           1410
# Name: count, Length: 107, dtype: int64

# %% [markdown]
# #### Double Checking if Salsa products have been removed

# %%
salsa_products_data_filtered = transaction_data[transaction_data['PROD_NAME'].str.contains("salsa", case=False)]

num_salsa_products_filtered = salsa_products_data_filtered.shape[0]

print(f"Number of 'salsa' products in filtered data: {num_salsa_products_filtered}")

salsa_products_summary_filtered = salsa_products_data_filtered['PROD_NAME'].value_counts()

print(salsa_products_summary_filtered)
# Out:
# Number of 'salsa' products in filtered data: 2928
# PROD_NAME
# Smiths Crinkle Cut  Tomato Salsa 150g       1470
# Red Rock Deli SR    Salsa & Mzzrlla 150g    1458
# Name: count, dtype: int64

# %% [markdown]
# #### Checking for outliers

# %%
transaction_data.describe()
# Filtering out transactions with unusually high quantities, we found out max as 200 when mean is 2. 
outliers = transaction_data[transaction_data['PROD_QTY'] >= 100]
outliers
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0

# %% [markdown]
# #### Filtering outliers

# %%
customer_id_to_remove = outliers['LYLTY_CARD_NBR'].iloc[0]
transaction_data = transaction_data[transaction_data['LYLTY_CARD_NBR'] != customer_id_to_remove]

# %% [markdown]
# #### Checking for missing transaction dates and replacing them with 0

# %%
# Creating a complete date range for the analysis period
date_range = pd.date_range(start="2018-07-01", end="2019-06-30")

# Grouping the transaction data by date
transactions_by_day = transaction_data.groupby('DATE').size()

# Reindexing the grouped data to include all dates in the date range
transactions_by_day = transactions_by_day.reindex(date_range, fill_value=0)

# Ploting the number of transactions over time
plt.figure(figsize=(10, 6))
transactions_by_day.plot()
plt.xlabel('Date')
plt.ylabel('Number of Transactions')
plt.title('Transactions Over Time (Including Missing Dates)')
plt.show()

# %% [markdown]
# #### Analysing data to reveal chips pack size which is sold the most

# %%
# Extracting pack size from PROD_NAME using a raw string
transaction_data['PACK_SIZE'] = transaction_data['PROD_NAME'].str.extract(r'(\d+)').astype(int)

# Checking the distribution of PACK_SIZE
plt.figure(figsize=(10, 6))
sns.histplot(transaction_data['PACK_SIZE'], bins=15, kde=False)
plt.xlabel('Pack Size')
plt.ylabel('Number of Transactions')
plt.title('Distribution of Pack Sizes')
plt.show()

# %% [markdown]
# #### Adding additional row named brand for better analysis per brand sales

# %%
# Extracting brand names
transaction_data['BRAND'] = transaction_data['PROD_NAME'].str.split().str[0].str.upper()

# Cleaning brand names
brand_replacements = {
    "RED": "RRD", "SNBTS": "SUNBITES", "INFZNS": "INFUZIONS",
    "WW": "WOOLWORTHS", "SMITH": "SMITHS", "NCC": "NATURAL", 
    "DORITO": "DORITOS", "GRAIN": "GRNWVES"
}
transaction_data['BRAND'] = transaction_data['BRAND'].replace(brand_replacements)

# Checking the cleaned brand names
transaction_data['BRAND'].value_counts()
# Out:
# BRAND
# KETTLE        41288
# SMITHS        31823
# DORITOS       25224
# PRINGLES      25102
# RRD           17779
# INFUZIONS     14201
# THINS         14075
# WOOLWORTHS    11836
# COBS           9693
# TOSTITOS       9471
# TWISTIES       9454
# GRNWVES        7740
# NATURAL        7469
# TYRRELLS       6442
# CHEEZELS       4603
# CCS            4551
# SUNBITES       3008
# CHEETOS        2927
# BURGER         1564
# FRENCH         1418
# Name: count, dtype: int64

# %% [markdown]
# #### Exploring Customer data

# %%
# Summary of customer data
customer_data.info()

# Check distributions of key columns
customer_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %% [markdown]
# #### Merging Transaction data and Customer data

# %%
merged_data = pd.merge(transaction_data, customer_data, how='left', on='LYLTY_CARD_NBR')

# Checking for any unmatched customer details (i.e., null values)
merged_data.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PACK_SIZE           0
# BRAND               0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %% [markdown]
# #### Analysing total sales by Lifestage and Premium Customers
# ##### --> This shows which customer segments contribute most to chip sales

# %%
# Calculating total sales by LIFESTAGE and PREMIUM_CUSTOMER
sales_by_segment = merged_data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().reset_index()

# Ploting the total sales by segment
plt.figure(figsize=(10, 6))
sns.barplot(data=sales_by_segment, x='LIFESTAGE', y='TOT_SALES', hue='PREMIUM_CUSTOMER')
plt.title('Total Sales by Lifestage and Premium Customer')
plt.ylabel('Total Sales')
plt.xlabel('Lifestage')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Analytics of Average number of units per customer by life stage and Premium Customer

# %%
# Calculating average number of units per customer by segment
units_per_customer = merged_data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['PROD_QTY'].mean().reset_index()

# Ploting the average number of units per customer
plt.figure(figsize=(10, 6))
sns.barplot(data=units_per_customer, x='LIFESTAGE', y='PROD_QTY', hue='PREMIUM_CUSTOMER')
plt.title('Average Number of Units per Customer by Lifestage and Premium Customer')
plt.ylabel('Average Number of Units')
plt.xlabel('Lifestage')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Analytics of Average Price per unit by Lifestage and Premium Customer

# %%
# Calculating average price per unit by segment
price_per_unit = merged_data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].mean().reset_index()

# Ploting the average price per unit
plt.figure(figsize=(10, 6))
sns.barplot(data=price_per_unit, x='LIFESTAGE', y='TOT_SALES', hue='PREMIUM_CUSTOMER')
plt.title('Average Price per Unit by Lifestage and Premium Customer')
plt.ylabel('Average Price')
plt.xlabel('Lifestage')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### T-Testing
# ##### --> We are comparing the total sales (TOT_SALES) between two groups of customers: "Mainstream" and "Premium" customers who are in the "Young Singles/Couples" life stage. We want to see if the average sales differ significantly between these two groups.

# %%
from scipy.stats import ttest_ind

# Filtering data for Mainstream and Premium customers in the Young Singles/Couples segment
mainstream = merged_data[(merged_data['PREMIUM_CUSTOMER'] == 'Mainstream') & (merged_data['LIFESTAGE'] == 'YOUNG SINGLES/COUPLES')]
premium = merged_data[(merged_data['PREMIUM_CUSTOMER'] == 'Premium') & (merged_data['LIFESTAGE'] == 'YOUNG SINGLES/COUPLES')]

# Calculating the mean TOT_SALES for both segments
mainstream_mean = mainstream['TOT_SALES'].mean()
premium_mean = premium['TOT_SALES'].mean()

# Printing the means
print(f"Mean TOT_SALES for Mainstream customers: {mainstream_mean}")
print(f"Mean TOT_SALES for Premium customers: {premium_mean}")

# Performing the T-test
t_stat, p_value = ttest_ind(mainstream['TOT_SALES'], premium['TOT_SALES'])

# Printing the T-test results
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# Mean TOT_SALES for Mainstream customers: 7.527896472976402
# Mean TOT_SALES for Premium customers: 6.649974649315531
# T-statistic: 23.580605847140326, P-value: 1.2057627361190008e-121

# %% [markdown]
# #### Observation on T-Test for TOT_SALES between Mainstream and Premium Customers
#
# The analysis compared the mean total sales (`TOT_SALES`) between "Mainstream" and "Premium" customers within the "Young Singles/Couples" segment.
#
# - **Mean TOT_SALES**:
#   - **Mainstream customers**: 7.53
#   - **Premium customers**: 6.65
#
# The results show that "Mainstream" customers have a higher average total sales compared to "Premium" customers.
#
# - **T-test Results**:
#   - **T-statistic**: 23.58
#   - **P-value**: 1.21e-121
#
# Given the extremely low P-value, which is much smaller than any conventional significance level (e.g., 0.05), we reject the null hypothesis that there is no difference in mean TOT_SALES between the two groups. This suggests a statistically significant difference in total sales between "Mainstream" and "Premium" customers in this segment, with "Mainstream" customers spending more on average.

# %% [markdown]
# #### Visualising the average spending by Customer type for which we completed T-testing above

# %%
mean_data = pd.DataFrame({
    'Customer Type': ['Mainstream', 'Premium'],
    'Average Spending': [mainstream_mean, premium_mean]
})

# Manually specifying colors for the bars
colors = ['#1f77b4', '#aec7e8']  # Using Matplotlib's default color palette

# Ploting using Matplotlib directly for better control over colors
plt.figure(figsize=(8, 4))
plt.bar(mean_data['Customer Type'], mean_data['Average Spending'], color=colors)
plt.ylabel('Average Spending ($)')
plt.title('Average Spending by Customer Type in Young Singles/Couples Segment')
plt.ylim(0, mean_data['Average Spending'].max() * 1.2)
plt.show()

# %% [markdown]
# #### Analyzing brand preference in main stream young singles/couples

# %%
mainstream_young = merged_data[(merged_data['LIFESTAGE'] == 'YOUNG SINGLES/COUPLES') & (merged_data['PREMIUM_CUSTOMER'] == 'Mainstream')]

# Count the frequency of brands purchased by this segment
brand_preference = mainstream_young['BRAND'].value_counts()

# Plot the brand preference
plt.figure(figsize=(12, 8))
sns.barplot(x=brand_preference.index, y=brand_preference.values)
plt.title('Brand Preference in Mainstream Young Singles/Couples')
plt.ylabel('Number of Purchases')
plt.xlabel('Brand')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Data Aggregation and Visualisation
#
# We are now calculating total sales by `LIFESTAGE` and `PREMIUM_CUSTOMER`, then visualising it with a heatmap.
#
# #### Key Steps:
# 1. Grouping data by `LIFESTAGE` and `PREMIUM_CUSTOMER`.
# 2. Visualising the results with a heatmap, showing sales distribution across segments.

# %%
# Calculating total sales by LIFESTAGE and PREMIUM_CUSTOMER
sales = merged_data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().unstack()

# Ploting a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(sales, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title("Total Sales by Lifestage and Premium Customer Flag")
plt.xlabel("Premium Customer")
plt.ylabel("Lifestage")
plt.show()

# %% [markdown]
# #### Visualising Unique Customers by Lifestage and Premium Customer Flag
#
# We are now calculating the number of unique customers by `LIFESTAGE` and `PREMIUM_CUSTOMER`, then visualises it using a heatmap.
#
# ##### Steps:
# 1. **Group Data**: Counting unique customers by `LIFESTAGE` and `PREMIUM_CUSTOMER`.
# 2. **Pivot Data**: Reshaping for heatmap visualidation.
# 3. **Plot Heatmap**: Displaying the customer distribution across segments.

# %%
customers = merged_data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['LYLTY_CARD_NBR'].nunique().reset_index()
customers.columns = ['LIFESTAGE', 'PREMIUM_CUSTOMER', 'CUSTOMERS']

# Pivoting the data for the heatmap
customers_pivot = customers.pivot(index='LIFESTAGE', columns='PREMIUM_CUSTOMER', values='CUSTOMERS')

# Ploting a heatmap to visualize the proportion of customers
plt.figure(figsize=(10, 6))
sns.heatmap(customers_pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Proportion of Customers by Lifestage and Premium Customer Flag")
plt.xlabel("Premium Customer")
plt.ylabel("Lifestage")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Analysing Brand Affinity for Mainstream, Young Singles/Couples
#
# This analysis compares brand affinity between the "Mainstream, Young Singles/Couples" segment and the rest of the population.
#
# ##### Steps:
# 1. **Segment Filtering**: Separating data for the target segment and others from `merged_data`.
# 2. **Calculate Quantities**: Determining product quantities for each segment.
# 3. **Brand Proportions**: Computing brand proportions within each segment.
# 4. **Brand Affinity**: Merging and calculate brand affinity, then sort by affinity score.

# %%
# Filter data for Mainstream, Young Singles/Couples segment
segment1 = merged_data[(merged_data['LIFESTAGE'] == "YOUNG SINGLES/COUPLES") & (merged_data['PREMIUM_CUSTOMER'] == "Mainstream")]

# Filter data for the rest of the population
other = merged_data[~((merged_data['LIFESTAGE'] == "YOUNG SINGLES/COUPLES") & (merged_data['PREMIUM_CUSTOMER'] == "Mainstream"))]

# Calculate total product quantity for segment1 and other
quantity_segment1 = segment1['PROD_QTY'].sum()
quantity_other = other['PROD_QTY'].sum()

# Calculate brand proportions for segment1 and other
quantity_segment1_by_brand = segment1.groupby('BRAND')['PROD_QTY'].sum().reset_index()
quantity_segment1_by_brand['targetSegment'] = quantity_segment1_by_brand['PROD_QTY'] / quantity_segment1

quantity_other_by_brand = other.groupby('BRAND')['PROD_QTY'].sum().reset_index()
quantity_other_by_brand['other'] = quantity_other_by_brand['PROD_QTY'] / quantity_other

# Merge and calculate brand affinity
brand_proportions = pd.merge(quantity_segment1_by_brand[['BRAND', 'targetSegment']], 
                             quantity_other_by_brand[['BRAND', 'other']], on='BRAND')
brand_proportions['affinityToBrand'] = brand_proportions['targetSegment'] / brand_proportions['other']

# Sort by affinity to brand
brand_proportions_sorted = brand_proportions.sort_values(by='affinityToBrand', ascending=False)
brand_proportions_sorted
# Out:
#          BRAND  targetSegment     other  affinityToBrand
# 18    TYRRELLS       0.031307  0.025387         1.233215
# 17    TWISTIES       0.045824  0.037426         1.224402
# 5      DORITOS       0.121806  0.099872         1.219616
# 9       KETTLE       0.196445  0.163584         1.200882
# 16    TOSTITOS       0.045057  0.037526         1.200698
# 11    PRINGLES       0.118491  0.099437         1.191617
# 4         COBS       0.044290  0.038584         1.147889
# 8    INFUZIONS       0.064176  0.056386         1.138160
# 15       THINS       0.059903  0.056308         1.063839
# 7      GRNWVES       0.032458  0.030817         1.053246
# 3     CHEEZELS       0.017831  0.018425         0.967771
# 13      SMITHS       0.098852  0.129107         0.765660
# 6       FRENCH       0.003917  0.005690         0.688427
# 2      CHEETOS       0.007971  0.011923         0.668508
# 12         RRD       0.048016  0.072583         0.661529
# ...

# %% [markdown]
# #### Summary on Brand Affinity for "Mainstream, Young Singles/Couples" Segment
#
# The analysis reveals that the "Mainstream, Young Singles/Couples" segment has the highest affinity for the following brands:
#
# 1. **TYRRELLS**: With an affinity score of 1.233, this brand is particularly favored by the target segment, indicating they purchase this brand 23.3% more than the rest of the population.
# 2. **TWISTIES**: Close behind, with an affinity score of 1.224, showing a strong preference by the segment.
# 3. **DORITOS, KETTLE, TOSTITOS, and PRINGLES**: These brands also have high affinity scores above 1.19, making them popular choices within this segment.
#
# On the other hand, brands like **BURGER**, **WOOLWORTHS**, and **SUNBITES** have significantly lower affinity scores, indicating that these brands are less favored by the target segment compared to the general population.
#
# This insight suggests that marketing efforts for the "Mainstream, Young Singles/Couples" segment could be more effective if focused on the top-affinity brands such as TYRRELLS, TWISTIES, and DORITOS.

# %% [markdown]
# ## **Conclusion**
#
# The analysis provided several valuable insights into the purchasing behavior of the supermarket's customers, particularly in the chip category:
#
# 1. **Key Customer Segments:**
#    - The **"Mainstream, Young Singles/Couples"** segment emerged as a significant driver of chip sales, showing a strong preference for brands like **TYRRELLS**, **TWISTIES**, and **DORITOS**. This segment's purchasing behavior suggests a high level of engagement, making it a prime target for marketing campaigns.
#
# 2. **Sales Performance:**
#    - A detailed comparison between **"Mainstream"** and **"Premium"** customers within the "Young Singles/Couples" segment revealed that **"Mainstream"** customers spend significantly more on average. This insight indicates an opportunity to tailor promotions and offers specifically for **"Mainstream"** customers to further boost sales.
#
# 3. **Brand Affinity:**
#    - The brand affinity analysis highlighted that the **"Mainstream, Young Singles/Couples"** segment has a particularly high affinity for **TYRRELLS** and **TWISTIES**, purchasing these brands significantly more than the rest of the population. On the other hand, brands like **BURGER**, **WOOLWORTHS**, and **SUNBITES** have lower affinity scores, suggesting these brands are less appealing to this segment.
#
# ### **Recommendations:**
#
# - **Targeted Marketing:**
#   - Focus marketing efforts on the **"Mainstream, Young Singles/Couples"** segment by promoting high-affinity brands such as **TYRRELLS**, **TWISTIES**, and **DORITOS**. This targeted approach is likely to yield better engagement and higher sales.
#
# - **Product Placement:**
#   - Strategically place high-affinity brands in prominent locations within the supermarket to attract the **"Mainstream, Young Singles/Couples"** segment. Consider special promotions or discounts on these brands to encourage repeat purchases.
#
# - **Inventory Management:**
#   - Adjust inventory levels to ensure that high-affinity brands are well-stocked, especially during peak shopping periods. This will help meet the demand from the target segment and avoid stockouts that could lead to lost sales.
#
# By implementing these recommendations, the supermarket can better align its product offerings with customer preferences, driving growth in the chip category and enhancing overall customer satisfaction.
